# %%
import pandas as pd

# %%
#Datos de los costos marginales reales observados
df_cost_marg=pd.read_csv("costo_marginal_real.csv")
df_cm_muestra = df_cost_marg.sample(120000, random_state=72)

# %%
#Datos de los costos marginales previstos por el sistema 
df_cost_prog=pd.read_csv("costo_marginal_programado.csv")
ind=df_cost_prog['mnemotecnico_barra'] == '-'
df=df_cost_prog[~ind]
df_cp_muestra = df.sample(100000, random_state=72)

# %%
df1=df_cm_muestra.sort_values(['fecha','hora'], ascending=False)

# %%
df2=df_cp_muestra.sort_values(['fecha','hora'], ascending=False)
df2.head()
# Out:
#         mnemotecnico_barra                       nombre_barra       fecha  \
# 984282   BA02T005SE142T005             BA S/E CORONEL 15KV B1  2019-06-30
# 1184585  BA02T003SE004T003              BA S/E CHOLGUAN 220KV  2019-06-30
# 983610   BA01G004SE035G004            BA S/E CANUTILLAR JBP-A  2019-06-30
# 984738   BA01R002SE015R002           BA S/E FLORIDA 110KV BP1  2019-06-30
# 984162   BA02T002SE012T002  BA S/E CONCEPCION 154KV SECCION 1  2019-06-30
#
#          hora      costo
# 984282     24  42.053637
# 1184585    24  42.169976
# 983610     24  41.037523
# 984738     24  44.820652
# 984162     24  43.088842

# %%
df=pd.merge(left = df1, right = df2, left_on=['barra_mnemotecnico', 'fecha', 'hora'], right_on=['mnemotecnico_barra', 'fecha', 'hora'] )
df
# Out:
#      barra_mnemotecnico barra_referencia_mnemotecnico       fecha  hora  \
# 0     BA01T002SE053T002             BA02T002SE032T002  2019-06-30    23
# 1     BA02T002SE033T002             BA02T002SE032T002  2019-06-30    19
# 2     BA05T002SE002T002             BA02T002SE032T002  2019-06-30    16
# 3     BA01T002SE098T002             BA02T002SE032T002  2019-06-30    12
# 4     BA03G011SE001G011             BA02T002SE032T002  2019-06-30    10
# ...                 ...                           ...         ...   ...
# 2458  BA28T025SE063T025             BA02T002SE032T002  2019-01-01     7
# 2459  BA48T027SE123G216             BA02T002SE032T002  2019-01-01     5
# 2460  BA68T005SE277T005             BA02T002SE032T002  2019-01-01     3
# 2461  BA02T002SE032T002             BA02T002SE032T002  2019-01-01     2
# 2462  BA56G216SE023G216             BA02T002SE032T002  2019-01-01     1
#
#       costo_en_dolares  costo_en_pesos                              nombre  \
# ...

# %%
len(df)
# Out:
# 10900340

# %%
df_cp_muestra['mnemotecnico_barra'].unique
# Out:
# <bound method Series.unique of 389529     BA03G010SE054G010
# 1169601    BA01T002SE036T002
# 624754     BA69L124SE177L124
# 263707     BA01T002SE029T002
# 591351     BA01G021SE018G021
#                  ...
# 805877     BA21L108SE013L135
# 61603      BA05T005SE288T005
# 169536     BA02T003SE002T003
# 849905     BA01R002SE033R002
# 1005014                    -
# Name: mnemotecnico_barra, Length: 100000, dtype: object>

# %%
fil_dupli=df_cp_muestra[df_cp_muestra.duplicated(['mnemotecnico_barra', 'fecha', 'hora'])]
fil_dupli
# Out:
#         mnemotecnico_barra                     nombre_barra       fecha  hora  \
# 1176556  BA02T003SE004T003            BA S/E CHOLGUAN 220KV  2019-01-14    13
# 1192074  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-05    23
# 1168800  BA01T002SE036T002    BA S/E SAUZAL 110KV SECCION 1  2019-02-03    11
# 1188974  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-04-02    21
# 1189191  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-04-06    21
# ...                    ...                              ...         ...   ...
# 1191009  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-05-14    14
# 1169619  BA01T002SE036T002    BA S/E SAUZAL 110KV SECCION 1  2019-02-20    14
# 1177335  BA02T003SE004T003            BA S/E CHOLGUAN 220KV  2019-01-30    24
# 1179123  BA02T003SE004T003            BA S/E CHOLGUAN 220KV  2019-03-09    12
# 1174668  BA01T002SE036T002    BA S/E SAUZAL 110KV SECCION 1  2019-06-05    21
#
#              costo
# ...

# %%
a=pd.merge(left = df_cm_muestra, right = df_cp_muestra, left_on='barra_mnemotecnico', right_on='mnemotecnico_barra' )
a.head()
# Out:
#   barra_mnemotecnico barra_referencia_mnemotecnico     fecha_x  hora_x  \
# 0  BA01G006SE001G104             BA02T002SE032T002  2019-04-11      13
# 1  BA01G006SE001G104             BA02T002SE032T002  2019-04-11      13
# 2  BA01G006SE001G104             BA02T002SE032T002  2019-04-11      13
# 3  BA01G006SE001G104             BA02T002SE032T002  2019-04-11      13
# 4  BA01G006SE001G104             BA02T002SE032T002  2019-04-11      13
#
#    costo_en_dolares  costo_en_pesos                nombre mnemotecnico_barra  \
# 0               0.0             0.0  BA S/E TALINAY 220KV  BA01G006SE001G104
# 1               0.0             0.0  BA S/E TALINAY 220KV  BA01G006SE001G104
# 2               0.0             0.0  BA S/E TALINAY 220KV  BA01G006SE001G104
# 3               0.0             0.0  BA S/E TALINAY 220KV  BA01G006SE001G104
# 4               0.0             0.0  BA S/E TALINAY 220KV  BA01G006SE001G104
#
#            nombre_barra     fecha_y  hora_y      costo
# ...

# %%
df_cm_muestra.head()
# Out:
#         barra_mnemotecnico barra_referencia_mnemotecnico       fecha  hora  \
# 2232576  BA01G006SE001G104             BA02T002SE032T002  2019-04-11    13
# 4027090  BA40G064SE085G064             BA02T002SE032T002  2019-04-10    23
# 2543844  BA01R003SE003R003             BA02T002SE032T002  2019-02-22    15
# 1268112  BA01L018SE004L018             BA02T002SE032T002  2019-02-03     8
# 4198878  BA01R002SE012R002             BA02T002SE032T002  2019-04-02    24
#
#          costo_en_dolares  costo_en_pesos  \
# 2232576              0.00         0.00000
# 4027090             50.32        33.36266
# 2543844             57.49        37.62835
# 1268112             53.49        35.18626
# 4198878             62.58        42.46241
#
#                                          nombre
# 2232576                    BA S/E TALINAY 220KV
# 4027090                     BA S/E INACESA 23KV
# 2543844  BA S/E ALTO MELIPILLA BARRA 220KV N° 1
# 1268112                  BA S/E ALGARROBO 110KV
# ...

# %%
df_cost_marg.head()
# Out:
#   barra_mnemotecnico barra_referencia_mnemotecnico       fecha  hora  \
# 0  BA01T005SE075T005             BA02T002SE032T002  2019-04-06    25
# 1  BA01T005SE175T005             BA02T002SE032T002  2019-04-06    25
# 2  BA03R002SE002R002             BA02T002SE032T002  2019-04-06    25
# 3  BA01R002SE012R002             BA02T002SE032T002  2019-04-06    25
# 4  BA03R002SE013R002             BA02T002SE032T002  2019-04-06    25
#
#    costo_en_dolares  costo_en_pesos  \
# 0             62.24        41.47176
# 1             62.56        41.68498
# 2             60.04        40.00585
# 3             61.65        41.07863
# 4             59.55        39.67936
#
#                                            nombre
# 0                              BA S/E LORETO 15KV
# 1                            BA S/E RETIRO 13.2KV
# 2                    BA S/E ALTAMIRANO 12.5KV BP1
# 3                         BA S/E CURACAVI 44KV B1
# 4  BA S/E EL MANZANO (ENEL DISTRIBUCIÓN) 23KV BP1

# %%
df_cost_prog.head()
# Out:
#   mnemotecnico_barra                        nombre_barra       fecha  hora  \
# 0  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     1
# 1  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     2
# 2  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     3
# 3  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     4
# 4  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     5
#
#        costo
# 0  49.897334
# 1  50.471616
# 2  50.077821
# 3  49.796216
# 4  49.796216

# %%
#Para verificar si hay filas duplicadas tomandando en cuanta las columnas
#mnemotecnico_barra, fecha, hora
fil_dupli=df_cost_prog[df_cost_prog.duplicated(['mnemotecnico_barra', 'fecha', 'hora'])]
fil_dupli
# Out:
#         mnemotecnico_barra                     nombre_barra       fecha  hora  \
# 987115                   -                                -  2019-01-01     1
# 987116                   -                                -  2019-01-01     2
# 987117                   -                                -  2019-01-01     3
# 987118                   -                                -  2019-01-01     4
# 987119                   -                                -  2019-01-01     5
# ...                    ...                              ...         ...   ...
# 1192119  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    20
# 1192120  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    21
# 1192121  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    22
# 1192122  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    23
# 1192123  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    24
#
#               costo
# ...

# %%
#Verifico si hay duplicados
df_cp[df_cp.duplicated(['mnemotecnico_barra', 'fecha', 'hora'])]

# %%
ind=df_cp['mnemotecnico_barra']=='-'
df_cp_=df_cp[~ind]

# %%
ind=df_cost_prog['mnemotecnico_barra'] == '-'
df=df_cost_prog[~ind]
df
# Out:
#         mnemotecnico_barra                        nombre_barra       fecha  \
# 0        BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01
# 1        BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01
# 2        BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01
# 3        BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01
# 4        BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01
# ...                    ...                                 ...         ...
# 1192119  BA83L131SE134L131     BA S/E SIERRA GORDA 220KV - BP1  2019-06-06
# 1192120  BA83L131SE134L131     BA S/E SIERRA GORDA 220KV - BP1  2019-06-06
# 1192121  BA83L131SE134L131     BA S/E SIERRA GORDA 220KV - BP1  2019-06-06
# 1192122  BA83L131SE134L131     BA S/E SIERRA GORDA 220KV - BP1  2019-06-06
# 1192123  BA83L131SE134L131     BA S/E SIERRA GORDA 220KV - BP1  2019-06-06
#
#          hora      costo
# 0           1  49.897334
# ...

# %%
fil_dupli=df[df.duplicated(['mnemotecnico_barra', 'fecha', 'hora'])]
fil_dupli
# Out:
#         mnemotecnico_barra                     nombre_barra       fecha  hora  \
# 1167230  BA01T002SE036T002    BA S/E SAUZAL 110KV SECCION 1  2019-01-01     1
# 1167231  BA01T002SE036T002    BA S/E SAUZAL 110KV SECCION 1  2019-01-01     2
# 1167232  BA01T002SE036T002    BA S/E SAUZAL 110KV SECCION 1  2019-01-01     3
# 1167233  BA01T002SE036T002    BA S/E SAUZAL 110KV SECCION 1  2019-01-01     4
# 1167234  BA01T002SE036T002    BA S/E SAUZAL 110KV SECCION 1  2019-01-01     5
# ...                    ...                              ...         ...   ...
# 1192119  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    20
# 1192120  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    21
# 1192121  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    22
# 1192122  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    23
# 1192123  BA83L131SE134L131  BA S/E SIERRA GORDA 220KV - BP1  2019-06-06    24
#
#              costo
# ...

# %%
df=df.drop_duplicates(subset=['mnemotecnico_barra', 'fecha', 'hora'])

# %%
df.head()
# Out:
#   mnemotecnico_barra                        nombre_barra       fecha  hora  \
# 0  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     1
# 1  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     2
# 2  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     3
# 3  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     4
# 4  BA01T002SE002T002  BA S/E ALTO JAHUEL 110KV SECCION 1  2019-01-01     5
#
#        costo
# 0  49.897334
# 1  50.471616
# 2  50.077821
# 3  49.796216
# 4  49.796216

# %%
pd.merge(left = df_cm_muestra, right = df_cp_muestra, left_on='barra_mnemotecnico', right_on='mnemotecnico_barra' )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-76eab07953b4> in <module>
# ----> 1 pd.merge(left = df_cm_muestra, right = df_cp_muestra, left_on='barra_mnemotecnico', right_on='mnemotecnico_barra' )
#
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
# ...

# %%
#pd.unique(df_cost_marg['barra_mnemotecnico']).tolist()

# %%
#pd.unique(df_cost_prog['mnemotecnico_barra'])
#df_cost_prog.value_counts()

# %%
df_cost_prog.columns.tolist()

# %%
#Se modifica el nombre de la primera columna de df_cost_prog, y se pasa la lista
#con todos los nombres, para poder realizar el marge

df_cost_prog.columns= ['barra_mnemotecnico', 'nombre_barra', 'fecha', 'hora', 'costo']

# %%
pd.merge(df_cost_marg, df_cost_prog, on='barra_mnemotecnico' )

# %%
df_cost_prog.head()

# %%
df_cost_marg.isna().sum()

# %%
df_cost_prog.isna().sum()

# %%
df_cost_prog.dtypes

# %%
df_cost_prog.duplicated(['mnemotecnico_barra'],keep=False)

# %%
df_cost_prog[df_cost_prog.duplicated(keep=False)]

# %%
df_cost_prog.columns.tolist()

# %%
fil_dupli=df_cost_prog[df_cost_prog.duplicated(['mnemotecnico_barra', 'fecha', 'hora'])]
fil_dupli

# %%
df_cost_prog.drop_duplicates(subset=['mnemotecnico_barra', 'fecha', 'hora'])

# %%
pd.unique(fil_dupli['mnemotecnico_barra'])

# %%
df_cost_marg[df_cost_marg.duplicated(['barra_mnemotecnico', 'fecha', 'hora'])]

# %%
import pandas as pd

    # List of Tuples
students = [('jack', 34, 'Sydeny'),
            ('Riti', 30, 'Delhi'),
            ('Aadi', 16, 'New York'),
            ('Riti', 30, 'Delhi'),
            ('Riti', 30, 'Delhi'),
            ('Riti', 30, 'Mumbai'),
            ('Aadi', 40, 'London'),
            ('Sachin', 30, 'Delhi')
            ]
# Create a DataFrame object
dfObj = pd.DataFrame(students, columns=['Name', 'Age', 'City'])

# %%
duplicateRowsDF = dfObj[dfObj.duplicated(keep=False)]
duplicateRowsDF

# %%
df[duplicated(df[, c('mnemotecnico_barra', 'fecha', 'hora')]), ]
ind=which(df['mnemotecnico_barra']=='-')
length(ind)
df_=df[-ind,]
nrow(df_)
df_[duplicated(df_[, c('mnemotecnico_barra', 'fecha', 'hora')]), ]

# %%
costo_marginal=pd.merge(df_cm,df_cp,left_on=['barra_mnemotecnico', 'fecha', 'hora'],right_on=['mnemotecnico_barra', 'fecha', 'hora'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

times = pd.date_range('2015-10-06', periods=500, freq='10min')

fig, ax = plt.subplots(1)
fig.autofmt_xdate()
plt.plot(times, range(times.size))

xfmt = mdates.DateFormatter('%d-%m-%y %H:%M')
ax.xaxis.set_major_formatter(xfmt)

plt.show()

# %%
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np

dates = ['06/2015','07/2015','08/2015', '06/2016','07/2016','08/2016']
x = [dt.datetime.strptime(d,'%m/%Y').date() for d in dates]
y = range(len(x)) + np.random.random(len(x))

#Plot vs dates
fig, ax = plt.subplots(2,1)
ax[0].plot(x,y,'r.')

#Plot vs number and label
ax[1].plot(y,'r.')
ax[1].set_xticks(range(len(y)))
ax[1].set_xticklabels(dates)
plt.show()
